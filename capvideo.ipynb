# %%
#1: Load model_weights and create caption a frame function
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import image
from keras.models import load_model, Model

import matplotlib.pyplot as plt
import pickle
import numpy as np

import warnings
warnings.filterwarnings("ignore")



model = load_model("./model_weights/model_9.h5")
model._make_predict_function()

model_temp = ResNet50(weights="imagenet", input_shape=(224,224,3))

# Create a new model, by removing the last layer (output layer of 1000 classes) from the resnet50
model_resnet = Model(model_temp.input, model_temp.layers[-2].output)
model_resnet._make_predict_function()


    
# Load the word_to_idx and idx_to_word from disk

with open("./storage/word_to_idx.pkl", "rb") as w2i:
    word_to_idx = pickle.load(w2i)

with open("./storage/idx_to_word.pkl", "rb") as i2w:
    idx_to_word = pickle.load(i2w)
    

max_len = 35


def preprocess_image(img):
    img = image.load_img(img, target_size=(224,224))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

def encode_image(img):
    img = preprocess_image(img)
    feature_vector = model_resnet.predict(img)
    feature_vector = feature_vector.reshape(1, feature_vector.shape[1])
    return feature_vector



def predict_caption(photo):
    in_text = "startseq"

    for i in range(max_len):
        sequence = [word_to_idx[w] for w in in_text.split() if w in word_to_idx]
        sequence = pad_sequences([sequence], maxlen=max_len, padding='post')

        ypred =  model.predict([photo,sequence])
        ypred = ypred.argmax()
        word = idx_to_word[ypred]
        in_text+= ' ' +word

        if word =='endseq':
            break


    final_caption =  in_text.split()
    final_caption = final_caption[1:-1]
    final_caption = ' '.join(final_caption)

    return final_caption




def caption_this_image(input_img): 

    photo = encode_image(input_img)
    

    caption = predict_caption(photo)
    # keras.backend.clear_session()
    return caption
# Out:
# Using TensorFlow backend.
# C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\asus\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\asus\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py:3794: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\asus\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#test function
caption_this_image('E:/AI/Flicker8k_Dataset/1000268201_693b08cb0e.jpg')
# Out:
# 'woman in red shirt is sitting on bench'

# %%
# importing the necessary libraries 
import cv2 
import os
import pyodbc

#get the video's path and get video name i.e: D:/video/name.mp4 -> name
def get_video_name(input_video, suffix):
    end = int(input_video.rindex(suffix))
    start = int(input_video.rindex('/')) + 1
    video_name = input_video[start:end]
    return video_name

#calculate the similar rate between 2 strings ie: string1 = 'dog running in the grass', string2 = 'dog is running on the grass'
#>>>same_rate(string1, string2) >>> 0.8
def same_rate(prev, cur):
    temp = cur.split(' ')
    same = list(filter(lambda x: (prev.find(x) > -1) , temp))
    rate = len(same)/len(prev.split(' '))
    return rate

#initialize the connection to SQL server
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-OELBU86R\SQLEXPRESS;'
                      'Database=CaptionImage;'
                      'Trusted_Connection=yes;')
#define the cursor in pyodbc
cursor = conn.cursor()

#generate captions from video and optimize them, save them to server SQL
def caption_this_video(input_video, similar_rate):
    #create temporary folder called data to save the temporary caption image
    try:
        #creating a folder named data
        if not os.path.exists('data'):
            os.mkdir('data')
    except OSError:
        print('Error: Existed folder!')

    #delete the previous data in Caption Table
    delete_all_records = '''truncate table Caption'''
    cursor.execute(delete_all_records)
    conn.commit()    
    
    cap = cv2.VideoCapture(input_video)
    frame_number = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    seconds = float(frame_number / fps)
    duration = int(seconds*1000)
    print('frame num = ' + str(frame_number) + ' fps = ' + str(fps) + ' duration = ' + str(duration) + 'ms')
    video_name = get_video_name(input_video, '.mp4')
    print('Video name: ' + video_name + '.mp4')
    count = 0
    start = 0
    stop = 1
    prev_caption = ''
    #Insert query
    insert_records = '''INSERT INTO Caption(Start, Stop, Decription) VALUES(?,?,?)'''
    while(True):
        ret, frame = cap.read()
        if ret:
            cap.set(cv2.CAP_PROP_POS_MSEC, (count*500))
            temp_path = './data/' + video_name + '.jpg'
            cv2.imwrite(temp_path, frame)
            current_caption = caption_this_image(temp_path)
            r = same_rate(current_caption, prev_caption)
            if count == 0:
                prev_caption = current_caption
            elif (count > 0) and (r >= similar_rate):
                delta = duration-(count*500)
                if (delta < 500 and delta > 0):
                    cursor.execute(insert_records, str(start*500) + 'ms' , str(duration) + 'ms', current_caption)
                    conn.commit()
                    print('Done')
                #else:
                    #print('skip-------------------------------------------------------' + str(count))
            else:
                stop = count
                cursor.execute(insert_records, str(start*500) + 'ms' , str((stop)*500) + 'ms', prev_caption)
                conn.commit()
                start = stop
                prev_caption = current_caption
                
            os.remove(temp_path)
            count += 1
        else:
            print('DONE 100%')
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
#run this function to get the db
#input_video = 'D:/University/cat2.mp4'
input_video = 'D:/Adobe/Output/demo3.mp4'
caption_this_video(input_video,0.6)
# Out:
# frame num = 2868.0 fps = 30 duration = 95600ms
# Video name: demo3.mp4
# Done
# DONE 100%

# %%
import pyodbc
#initialize the connection to SQL server
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-OELBU86R\SQLEXPRESS;'
                      'Database=CaptionImage;'
                      'Trusted_Connection=yes;')
#define the cursor in pyodbc
cursor = conn.cursor()
#view all of the records in Caption table
select_record = '''SELECT * FROM Caption'''
cursor.execute(select_record)
for row in cursor:
    print(row)
# Out:
# ('demo2_30fps15533mslong                            ', '0ms       ', '3000ms    ', 'dog jumping in the air')
# ('demo2_30fps15533mslong                            ', '3000ms    ', '6500ms    ', 'two dogs are playing in the snow')
# ('demo2_30fps15533mslong                            ', '6500ms    ', '7000ms    ', 'dog jumping in the air')
# ('demo2_30fps15533mslong                            ', '7000ms    ', '9000ms    ', 'two dogs are playing with tennis ball in the grass')
# ('demo2_30fps15533mslong                            ', '9000ms    ', '11000ms   ', 'dog is jumping up in the air')
# ('demo2_30fps15533mslong                            ', '11000ms   ', '15000ms   ', 'two dogs are playing with tennis ball in the grass')
# ('demo2_30fps15533mslong                            ', '15000ms   ', '15533ms   ', 'woman in red jacket is sitting on the street')
# ('demo_30fps59433mslong                             ', '0ms       ', '2500ms    ', 'woman with long hair and woman in black dress are sitting in crowd of people')
# ('demo_30fps59433mslong                             ', '2500ms    ', '4500ms    ', 'man with mohawk hair and black hat is standing in front of some')
# ('demo_30fps59433mslong                             ', '4500ms    ', '5000ms    ', 'woman with long hair and beard and beard and black hair is holding camera')
# ('demo_30fps59433mslong                             ', '5000ms    ', '16000ms   ', 'woman with long hair and black hair and black hat is standing in front of some people')
# ('demo_30fps59433mslong                             ', '16000ms   ', '20000ms   ', 'two dogs are playing with tennis ball in the grass')
# ('demo_30fps59433mslong                             ', '20000ms   ', '21500ms   ', 'dog is playing with tennis ball in its mouth')
# ('demo_30fps59433mslong                             ', '21500ms   ', '25500ms   ', 'two dogs are playing in the grass')
# ('demo_30fps59433mslong                             ', '25500ms   ', '26000ms   ', 'dog is running on the grass')
# ('demo_30fps59433mslong                             ', '26000ms   ', '30000ms   ', 'two dogs are playing with tennis ball in the grass')
# ('demo_30fps59433mslong                             ', '30000ms   ', '32500ms   ', 'man in blue shirt and helmet is walking past the street')
# ('demo_30fps59433mslong                             ', '32500ms   ', '33000ms   ', 'man in red shirt and leather stands in front of car')
# ('demo_30fps59433mslong                             ', '33000ms   ', '35000ms   ', 'man in blue shirt and black shorts is walking on the street')
# ('demo_30fps59433mslong                             ', '35000ms   ', '37000ms   ', 'two people are riding in race car')
# ('demo_30fps59433mslong                             ', '37000ms   ', '39500ms   ', 'man in blue shirt and helmet is walking on the street')
# ('demo_30fps59433mslong                             ', '39500ms   ', '40000ms   ', 'two people in race race')
# ('demo_30fps59433mslong                             ', '40000ms   ', '40500ms   ', 'man in blue shirt and leather is walking through the streets')
# ('demo_30fps59433mslong                             ', '40500ms   ', '41500ms   ', 'two men are standing in front of house')
# ('demo_30fps59433mslong                             ', '41500ms   ', '42500ms   ', 'two women in the middle of the floor')
# ('demo_30fps59433mslong                             ', '42500ms   ', '43500ms   ', 'two girls are playing soccer in field')
# ('demo_30fps59433mslong                             ', '43500ms   ', '44000ms   ', 'two dogs are playing in the yard')
# ('demo_30fps59433mslong                             ', '44000ms   ', '46500ms   ', 'dog jumping in the air')
# ('demo_30fps59433mslong                             ', '46500ms   ', '50000ms   ', 'two dogs are playing in the snow')
# ('demo_30fps59433mslong                             ', '50000ms   ', '50500ms   ', 'dog jumping in the air')
# ('demo_30fps59433mslong                             ', '50500ms   ', '52500ms   ', 'two dogs are playing with tennis ball in the grass')
# ('demo_30fps59433mslong                             ', '52500ms   ', '54500ms   ', 'dog is jumping up in the air')
# ('demo_30fps59433mslong                             ', '54500ms   ', '58500ms   ', 'two dogs are playing with tennis ball in the grass')
# ('demo_30fps59433mslong                             ', '58500ms   ', '59433ms   ', 'woman in red jacket is sitting on the street')
# ('demo_30fps59433mslong                             ', '58500ms   ', '59500ms   ', 'woman in red sweater is sitting on blanket')
# ('new_30fps4166mslong                               ', '0ms       ', '1000ms    ', 'man is sitting on the edge of the mountain')
# ('new_30fps4166mslong                               ', '1000ms    ', '1500ms    ', 'woman with long hair and sunglasses is standing next to woman in black shirt')
# ('new_30fps4166mslong                               ', '1500ms    ', '4166ms    ', 'woman in black shirt and black shirt is sitting in front of white wall')
# ('carcwithgirl_24fps19333mslong                     ', '0ms       ', '1500ms    ', 'man in red shirt and jeans is holding up his arm')
# ('carcwithgirl_24fps19333mslong                     ', '1500ms    ', '2000ms    ', 'boy in red shirt and blue shorts is holding up his head and holding hands')
# ('carcwithgirl_24fps19333mslong                     ', '2000ms    ', '2500ms    ', 'man in red shirt is standing in front of large statue with his hands raised')
# ('carcwithgirl_24fps19333mslong                     ', '2500ms    ', '6500ms    ', 'boy in red shirt is holding up his head in the air')
# ('carcwithgirl_24fps19333mslong                     ', '6500ms    ', '7500ms    ', 'man in red shirt is standing in front of large rock')
# ('carcwithgirl_24fps19333mslong                     ', '7500ms    ', '13500ms   ', 'boy in red shirt is holding up his head in the air')
# ('carcwithgirl_24fps19333mslong                     ', '13500ms   ', '19333ms   ', 'man in red shirt is walking through the sand')
# ('car_23fps20739mslong                              ', '0ms       ', '2500ms    ', 'two people are walking on the beach')
# ('car_23fps20739mslong                              ', '2500ms    ', '3000ms    ', 'the dirt road in the desert')
# ('car_23fps20739mslong                              ', '3000ms    ', '3500ms    ', 'the man is riding horses on busy street')
# ('car_23fps20739mslong                              ', '3500ms    ', '4000ms    ', 'the dog is wearing blue shirt and black helmet')
# ('car_23fps20739mslong                              ', '4000ms    ', '6500ms    ', 'two people are walking along the beach')
# ('car_23fps20739mslong                              ', '6500ms    ', '7000ms    ', 'two riders are racing on dirt track')
# ('car_23fps20739mslong                              ', '7000ms    ', '7500ms    ', 'two people are riding horses on track')
# ('car_23fps20739mslong                              ', '7500ms    ', '8000ms    ', 'two people are walking along the beach')
# ('car_23fps20739mslong                              ', '8000ms    ', '8500ms    ', 'man in blue shirt is standing on the beach')
# ('car_23fps20739mslong                              ', '8500ms    ', '9000ms    ', 'man on the beach is attached of the desert')
# ('car_23fps20739mslong                              ', '9000ms    ', '9500ms    ', 'man in blue shirt is wearing white and black hat and helmet on the beach')
# ('car_23fps20739mslong                              ', '9500ms    ', '10000ms   ', 'two people are walking along the beach')
# ('car_23fps20739mslong                              ', '10000ms   ', '10500ms   ', 'man in blue shirt is sitting on the beach')
# ('car_23fps20739mslong                              ', '10500ms   ', '11000ms   ', 'the dirt bike is in the desert')
# ('car_23fps20739mslong                              ', '11000ms   ', '13000ms   ', 'man in blue shirt is standing on the beach')
# ('car_23fps20739mslong                              ', '13000ms   ', '13500ms   ', 'flock of people are walking along sand')
# ('car_23fps20739mslong                              ', '13500ms   ', '18000ms   ', 'man is standing on the beach with their arms covering in the air')
# ('car_23fps20739mslong                              ', '18000ms   ', '19000ms   ', 'the man is wearing white shoes and white shoes')
# ('bongchay_30fps457833mslong                        ', '0ms       ', '6500ms    ', 'man in white shirt is standing on the beach')
# ('bongchay_30fps457833mslong                        ', '6500ms    ', '11500ms   ', 'man in black is jumping over white and white ramp')
# ('bongchay_30fps457833mslong                        ', '11500ms   ', '12500ms   ', 'two men playing game')
# ('bongchay_30fps457833mslong                        ', '12500ms   ', '13500ms   ', 'two men in red and white uniforms are playing game')
# ('bongchay_30fps457833mslong                        ', '13500ms   ', '14000ms   ', 'wrestler in blue shirt is jumping over the bat')
# ('bongchay_30fps457833mslong                        ', '14000ms   ', '16000ms   ', 'two men in wrestling game')
# ('bongchay_30fps457833mslong                        ', '16000ms   ', '18000ms   ', 'man in red shirt and black pants is jumping over white and white fence')
# ('bongchay_30fps457833mslong                        ', '18000ms   ', '18500ms   ', 'man in blue shirt and khaki pants is sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '18500ms   ', '19500ms   ', 'man in blue shirt and blue shorts is jumping over chain barrel')
# ('bongchay_30fps457833mslong                        ', '19500ms   ', '21000ms   ', 'man in red shirt and black helmet is jumping over red and white fence')
# ('bongchay_30fps457833mslong                        ', '21000ms   ', '22000ms   ', 'man in red shirt is pushing another boy in the air')
# ('bongchay_30fps457833mslong                        ', '22000ms   ', '22500ms   ', 'man in red shirt is sitting on the edge of the road')
# ('bongchay_30fps457833mslong                        ', '22500ms   ', '23500ms   ', 'man in red shirt and jeans is jumping over chain barrel')
# ('bongchay_30fps457833mslong                        ', '23500ms   ', '24500ms   ', 'man in red shirt and white shirt and white shirt is holding football')
# ('bongchay_30fps457833mslong                        ', '24500ms   ', '25000ms   ', 'two wrestlers reach to get ball in the air')
# ('bongchay_30fps457833mslong                        ', '25000ms   ', '25500ms   ', 'two men playing game in front of crowd')
# ('bongchay_30fps457833mslong                        ', '25500ms   ', '26000ms   ', 'two men in blue and white uniforms are playing cricket')
# ('bongchay_30fps457833mslong                        ', '26000ms   ', '26500ms   ', 'man in red shirt is jumping into the air')
# ('bongchay_30fps457833mslong                        ', '26500ms   ', '27500ms   ', 'man in blue shirt and black shorts is jumping over white and white dog')
# ('bongchay_30fps457833mslong                        ', '27500ms   ', '29000ms   ', 'two men in red and white jerseys are playing cricket')
# ('bongchay_30fps457833mslong                        ', '29000ms   ', '29500ms   ', 'two sumo wrestlers in match')
# ('bongchay_30fps457833mslong                        ', '29500ms   ', '30000ms   ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '30000ms   ', '30500ms   ', 'wrestler in black and white uniform is airborne')
# ('bongchay_30fps457833mslong                        ', '30500ms   ', '31000ms   ', 'three men in white are playing frisbee')
# ('bongchay_30fps457833mslong                        ', '31000ms   ', '32000ms   ', 'two men in red and white uniforms are playing football')
# ('bongchay_30fps457833mslong                        ', '32000ms   ', '32500ms   ', 'football player in red is being by crowd')
# ('bongchay_30fps457833mslong                        ', '32500ms   ', '33500ms   ', 'two men in red and white are playing football')
# ('bongchay_30fps457833mslong                        ', '33500ms   ', '34500ms   ', 'man in red and white uniform is playing cricket')
# ('bongchay_30fps457833mslong                        ', '34500ms   ', '35500ms   ', 'dog is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '35500ms   ', '39000ms   ', 'pitcher in blue and white uniform is pitching baseball')
# ('bongchay_30fps457833mslong                        ', '39000ms   ', '39500ms   ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '39500ms   ', '40000ms   ', 'two men in white are playing baseball')
# ('bongchay_30fps457833mslong                        ', '40000ms   ', '40500ms   ', 'baseball player in blue uniform is pitching baseball')
# ('bongchay_30fps457833mslong                        ', '40500ms   ', '41000ms   ', 'wrestler in the air is jumping over the air')
# ('bongchay_30fps457833mslong                        ', '41000ms   ', '41500ms   ', 'two men are playing baseball')
# ('bongchay_30fps457833mslong                        ', '41500ms   ', '42000ms   ', 'wrestler in blue is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '42000ms   ', '42500ms   ', 'two sumo wrestlers are jumping over the goal')
# ('bongchay_30fps457833mslong                        ', '42500ms   ', '43500ms   ', 'man in red shirt is sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '43500ms   ', '44000ms   ', 'dog jumps over hurdle')
# ('bongchay_30fps457833mslong                        ', '44000ms   ', '44500ms   ', 'two people are sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '44500ms   ', '46000ms   ', 'black and white dog is jumping over red and white obstacle')
# ('bongchay_30fps457833mslong                        ', '46000ms   ', '47000ms   ', 'baseball player in black and white uniform is jumping up to catch ball')
# ('bongchay_30fps457833mslong                        ', '47000ms   ', '48500ms   ', 'man in white shirt and white shorts is running in the sand')
# ('bongchay_30fps457833mslong                        ', '48500ms   ', '49000ms   ', 'baseball player in black uniform is jumping over the bat')
# ('bongchay_30fps457833mslong                        ', '49000ms   ', '49500ms   ', 'two wrestlers wrestlers in the air')
# ('bongchay_30fps457833mslong                        ', '49500ms   ', '50000ms   ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '50000ms   ', '50500ms   ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '50500ms   ', '51000ms   ', 'two female wrestlers are playing with ball in competition')
# ('bongchay_30fps457833mslong                        ', '51000ms   ', '55000ms   ', 'man in red shirt and black shorts is jumping over red and white bar')
# ('bongchay_30fps457833mslong                        ', '55000ms   ', '55500ms   ', 'two wrestlers wrestlers in the ring')
# ('bongchay_30fps457833mslong                        ', '55500ms   ', '56500ms   ', 'two men in red and white race car in front of crowd')
# ('bongchay_30fps457833mslong                        ', '56500ms   ', '57000ms   ', 'two wrestlers wrestlers in the ring')
# ('bongchay_30fps457833mslong                        ', '57000ms   ', '57500ms   ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '57500ms   ', '58000ms   ', 'two wrestlers wrestlers in the ring')
# ('bongchay_30fps457833mslong                        ', '58000ms   ', '58500ms   ', 'man in black shirt is sitting on the ground')
# ('bongchay_30fps457833mslong                        ', '58500ms   ', '59000ms   ', 'two people are sitting on the grass')
# ('bongchay_30fps457833mslong                        ', '59000ms   ', '59500ms   ', 'man in black shirt is jumping over red bull')
# ('bongchay_30fps457833mslong                        ', '59500ms   ', '61500ms   ', 'black and white dog is jumping over red and white obstacle')
# ('bongchay_30fps457833mslong                        ', '61500ms   ', '62000ms   ', 'the guys are playing football')
# ('bongchay_30fps457833mslong                        ', '62000ms   ', '62500ms   ', 'two football players are tackling frisbee')
# ('bongchay_30fps457833mslong                        ', '62500ms   ', '63000ms   ', 'man in red shirt and black helmet is playing with multi')
# ('bongchay_30fps457833mslong                        ', '63000ms   ', '63500ms   ', 'man in red shirt and jeans is jumping over red barrel')
# ('bongchay_30fps457833mslong                        ', '63500ms   ', '65000ms   ', 'boy in yellow shirt is stretching the air on the grass')
# ('bongchay_30fps457833mslong                        ', '65000ms   ', '65500ms   ', 'boy in yellow shirt is jumping over red barrel')
# ('bongchay_30fps457833mslong                        ', '65500ms   ', '66000ms   ', 'football player in red jersey is being tackled by crowd')
# ('bongchay_30fps457833mslong                        ', '66000ms   ', '66500ms   ', 'football player in red uniform is running with his arms around')
# ('bongchay_30fps457833mslong                        ', '66500ms   ', '67000ms   ', 'wrestler in blue is jumping over an audience')
# ('bongchay_30fps457833mslong                        ', '67000ms   ', '67500ms   ', 'two sumo wrestlers in black and white uniforms are playing with ball')
# ('bongchay_30fps457833mslong                        ', '67500ms   ', '69000ms   ', 'two men playing game in the air')
# ('bongchay_30fps457833mslong                        ', '69000ms   ', '70000ms   ', 'two men in white are playing frisbee')
# ('bongchay_30fps457833mslong                        ', '70000ms   ', '72000ms   ', 'man in blue shirt and black shorts is walking past the side of the road')
# ('bongchay_30fps457833mslong                        ', '72000ms   ', '72500ms   ', 'wrestler in blue uniform is jumping over the bat')
# ('bongchay_30fps457833mslong                        ', '72500ms   ', '73500ms   ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '73500ms   ', '75000ms   ', 'man in yellow shirt is jumping over red and white ramp')
# ('bongchay_30fps457833mslong                        ', '75000ms   ', '78000ms   ', 'man in purple shirt and black shorts is jumping over white and white fence')
# ('bongchay_30fps457833mslong                        ', '78000ms   ', '78500ms   ', 'dog jumps over hurdle')
# ('bongchay_30fps457833mslong                        ', '78500ms   ', '79500ms   ', 'two men are playing cricket in front of crowd')
# ('bongchay_30fps457833mslong                        ', '79500ms   ', '80000ms   ', 'dog is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '80000ms   ', '80500ms   ', 'woman in purple shirt and black shorts is playing with drums')
# ('bongchay_30fps457833mslong                        ', '80500ms   ', '81000ms   ', 'man in white shirt and white shorts is jumping over white and white dog')
# ('bongchay_30fps457833mslong                        ', '81000ms   ', '82000ms   ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '82000ms   ', '83500ms   ', 'man in red shirt and white shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '83500ms   ', '87000ms   ', 'baseball player in blue uniform is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '87000ms   ', '87500ms   ', 'two wrestlers are competing around in race')
# ('bongchay_30fps457833mslong                        ', '87500ms   ', '91500ms   ', 'pitcher in blue and white uniform hits ball in game')
# ('bongchay_30fps457833mslong                        ', '91500ms   ', '92000ms   ', 'two sumo wrestlers are playing with the ball in the air')
# ('bongchay_30fps457833mslong                        ', '92000ms   ', '92500ms   ', 'two men in red and white jerseys are playing cricket')
# ('bongchay_30fps457833mslong                        ', '92500ms   ', '93000ms   ', 'baseball player in red uniform is jumping up of the air')
# ('bongchay_30fps457833mslong                        ', '93000ms   ', '93500ms   ', 'two men in red and white jerseys are playing cricket')
# ('bongchay_30fps457833mslong                        ', '93500ms   ', '94000ms   ', 'wrestler in red jersey is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '94000ms   ', '94500ms   ', 'the athlete is performing trick on the course')
# ('bongchay_30fps457833mslong                        ', '94500ms   ', '95500ms   ', 'two men are sitting on the grass')
# ('bongchay_30fps457833mslong                        ', '95500ms   ', '96000ms   ', 'man in black shirt is jumping over red and white ramp')
# ('bongchay_30fps457833mslong                        ', '96000ms   ', '96500ms   ', 'man in red shirt is sitting on the street')
# ('bongchay_30fps457833mslong                        ', '96500ms   ', '98000ms   ', 'dog is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '98000ms   ', '99000ms   ', 'baseball player in black and white uniform is playing baseball')
# ('bongchay_30fps457833mslong                        ', '99000ms   ', '100000ms  ', 'dog is jumping up to get ball')
# ('bongchay_30fps457833mslong                        ', '100000ms  ', '100500ms  ', 'man in blue shirt and white shorts is playing tennis')
# ('bongchay_30fps457833mslong                        ', '100500ms  ', '109500ms  ', 'man in white shirt and white shorts is playing with the ball in the grass')
# ('bongchay_30fps457833mslong                        ', '109500ms  ', '111000ms  ', 'group of people are sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '111000ms  ', '113500ms  ', 'group of people are standing around in front of an audience')
# ('bongchay_30fps457833mslong                        ', '113500ms  ', '114000ms  ', 'dog is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '114000ms  ', '114500ms  ', 'dog is jumping up to catch ball')
# ('bongchay_30fps457833mslong                        ', '114500ms  ', '115000ms  ', 'dog jumps over hurdle')
# ('bongchay_30fps457833mslong                        ', '115000ms  ', '115500ms  ', 'two people are sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '115500ms  ', '116500ms  ', 'woman in purple dress is sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '116500ms  ', '118000ms  ', 'man in white shirt and white shorts is running in the field')
# ('bongchay_30fps457833mslong                        ', '118000ms  ', '118500ms  ', 'man in red shirt and black shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '118500ms  ', '119000ms  ', 'two men in red and white are playing football')
# ('bongchay_30fps457833mslong                        ', '119000ms  ', '120000ms  ', 'woman in blue shirt and blue shorts is running on the street')
# ('bongchay_30fps457833mslong                        ', '120000ms  ', '120500ms  ', 'woman in red shirt and black hat is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '120500ms  ', '121500ms  ', 'two people are sitting in the street')
# ('bongchay_30fps457833mslong                        ', '121500ms  ', '122500ms  ', 'woman in white dress is jumping over white and white motorcycle')
# ('bongchay_30fps457833mslong                        ', '122500ms  ', '123000ms  ', 'man in white shirt is playing with his dog')
# ('bongchay_30fps457833mslong                        ', '123000ms  ', '123500ms  ', 'two men in white are playing frisbee')
# ('bongchay_30fps457833mslong                        ', '123500ms  ', '124000ms  ', 'two wrestlers wrestlers in the air')
# ('bongchay_30fps457833mslong                        ', '124000ms  ', '124500ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '124500ms  ', '125500ms  ', 'two men in wrestling uniform playing game')
# ('bongchay_30fps457833mslong                        ', '125500ms  ', '126000ms  ', 'two wrestlers are competing in race')
# ('bongchay_30fps457833mslong                        ', '126000ms  ', '126500ms  ', 'two men are playing cricket in field')
# ('bongchay_30fps457833mslong                        ', '126500ms  ', '127000ms  ', 'two wrestlers in the ring')
# ('bongchay_30fps457833mslong                        ', '127000ms  ', '128000ms  ', 'two men in blue and white uniforms are playing game')
# ('bongchay_30fps457833mslong                        ', '128000ms  ', '128500ms  ', 'man in red shirt and black pants is jumping over white barrel')
# ('bongchay_30fps457833mslong                        ', '128500ms  ', '129000ms  ', 'two wrestlers wrestlers in the air')
# ('bongchay_30fps457833mslong                        ', '129000ms  ', '129500ms  ', 'man in green shirt is jumping over white and white motorcycle')
# ('bongchay_30fps457833mslong                        ', '129500ms  ', '130000ms  ', 'two people are sitting on the side of the road')
# ('bongchay_30fps457833mslong                        ', '130000ms  ', '130500ms  ', 'two people in red and white are racing car')
# ('bongchay_30fps457833mslong                        ', '130500ms  ', '131000ms  ', 'the is in the red and white and white car is falling up the road')
# ('bongchay_30fps457833mslong                        ', '131000ms  ', '132000ms  ', 'two people are sitting on the grass')
# ('bongchay_30fps457833mslong                        ', '132000ms  ', '132500ms  ', 'man in red shirt is sitting on the street')
# ('bongchay_30fps457833mslong                        ', '132500ms  ', '133000ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '133000ms  ', '133500ms  ', 'dog is running on the sand')
# ('bongchay_30fps457833mslong                        ', '133500ms  ', '134000ms  ', 'baseball player in black is pitching in the air')
# ('bongchay_30fps457833mslong                        ', '134000ms  ', '136000ms  ', 'man in white shirt and white shirt is running in front of crowd')
# ('bongchay_30fps457833mslong                        ', '136000ms  ', '136500ms  ', 'little girl in red shirt and blue shorts is running on the grass')
# ('bongchay_30fps457833mslong                        ', '136500ms  ', '137000ms  ', 'the dog is running in the field')
# ('bongchay_30fps457833mslong                        ', '137000ms  ', '137500ms  ', 'two people are sitting on the side of the starting')
# ('bongchay_30fps457833mslong                        ', '137500ms  ', '138000ms  ', 'horse is jumping over fence')
# ('bongchay_30fps457833mslong                        ', '138000ms  ', '138500ms  ', 'two men are playing frisbee on the grass')
# ('bongchay_30fps457833mslong                        ', '138500ms  ', '139000ms  ', 'horse leaps over the line as another audience watches')
# ('bongchay_30fps457833mslong                        ', '139000ms  ', '139500ms  ', 'two muzzled greyhounds are racing around track')
# ('bongchay_30fps457833mslong                        ', '139500ms  ', '141500ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '141500ms  ', '142000ms  ', 'dog is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '142000ms  ', '143000ms  ', 'girl in purple shirt and blue shorts is bouncing on the grass')
# ('bongchay_30fps457833mslong                        ', '143000ms  ', '143500ms  ', 'two men in blue and white uniforms are playing soccer')
# ('bongchay_30fps457833mslong                        ', '143500ms  ', '144000ms  ', 'man in white shirt and white shirt is jumping over white and white dog')
# ('bongchay_30fps457833mslong                        ', '144000ms  ', '144500ms  ', 'wrestler in ring is jumping over bull')
# ('bongchay_30fps457833mslong                        ', '144500ms  ', '145000ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '145000ms  ', '146000ms  ', 'man in blue shirt and black shorts is jumping over white and white bull')
# ('bongchay_30fps457833mslong                        ', '146000ms  ', '146500ms  ', 'two wrestlers are competing around an obstacle')
# ('bongchay_30fps457833mslong                        ', '146500ms  ', '147000ms  ', 'two people are sitting on the side of the road')
# ('bongchay_30fps457833mslong                        ', '147000ms  ', '147500ms  ', 'the dog is running through the streets')
# ('bongchay_30fps457833mslong                        ', '147500ms  ', '150000ms  ', 'two people are sitting on the street with their heads raised them')
# ('bongchay_30fps457833mslong                        ', '150000ms  ', '150500ms  ', 'man in green shirt is sitting on the lap of the')
# ('bongchay_30fps457833mslong                        ', '150500ms  ', '151000ms  ', 'two people are sitting on the street with their heads raised their heads')
# ('bongchay_30fps457833mslong                        ', '151000ms  ', '151500ms  ', 'man in red shirt is sitting on the street')
# ('bongchay_30fps457833mslong                        ', '151500ms  ', '152000ms  ', 'dog jumps over hurdle')
# ('bongchay_30fps457833mslong                        ', '152000ms  ', '152500ms  ', 'two wrestlers wrestlers in race')
# ('bongchay_30fps457833mslong                        ', '152500ms  ', '153500ms  ', 'man in blue shirt and black shorts is running on the sand')
# ('bongchay_30fps457833mslong                        ', '153500ms  ', '154000ms  ', 'two men in black are standing in front of an audience')
# ('bongchay_30fps457833mslong                        ', '154000ms  ', '154500ms  ', 'man in red shirt and white shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '154500ms  ', '155000ms  ', 'the football player in red is the ball in the foreground')
# ('bongchay_30fps457833mslong                        ', '155000ms  ', '155500ms  ', 'two men in red and white uniforms are playing cricket')
# ('bongchay_30fps457833mslong                        ', '155500ms  ', '156000ms  ', 'two people are sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '156000ms  ', '157000ms  ', 'wrestler in white shirt is raising the ball in the air')
# ('bongchay_30fps457833mslong                        ', '157000ms  ', '158000ms  ', 'wrestler in white shirt is jumping over white and white fence')
# ('bongchay_30fps457833mslong                        ', '158000ms  ', '158500ms  ', 'four wrestlers wrestlers in wrestling ring')
# ('bongchay_30fps457833mslong                        ', '158500ms  ', '159000ms  ', 'wrestler in white shirt is jumping up to get shot')
# ('bongchay_30fps457833mslong                        ', '159000ms  ', '159500ms  ', 'wrestler in white shirt is jumping over white and white fence')
# ('bongchay_30fps457833mslong                        ', '159500ms  ', '160000ms  ', 'group of people are playing frisbee')
# ('bongchay_30fps457833mslong                        ', '160000ms  ', '162500ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '162500ms  ', '163000ms  ', 'two men in blue and white uniforms are playing soccer')
# ('bongchay_30fps457833mslong                        ', '163000ms  ', '166000ms  ', 'baseball player in red and white uniform is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '166000ms  ', '167500ms  ', 'man in blue shirt is running on the beach')
# ('bongchay_30fps457833mslong                        ', '167500ms  ', '169000ms  ', 'man with long hair and black hat is sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '169000ms  ', '169500ms  ', 'woman in purple bathing suit is jogging on the beach')
# ('bongchay_30fps457833mslong                        ', '169500ms  ', '170000ms  ', 'jockey is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '170000ms  ', '170500ms  ', 'jockey in black shirt is riding on the street')
# ('bongchay_30fps457833mslong                        ', '170500ms  ', '171500ms  ', 'man in red shirt and black shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '171500ms  ', '173500ms  ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '173500ms  ', '174000ms  ', 'two men playing game in the air')
# ('bongchay_30fps457833mslong                        ', '174000ms  ', '174500ms  ', 'two men are playing cricket in field')
# ('bongchay_30fps457833mslong                        ', '174500ms  ', '175000ms  ', 'two sumo wrestlers are playing with ball')
# ('bongchay_30fps457833mslong                        ', '175000ms  ', '175500ms  ', 'two men in white are playing with ball in front of crowd')
# ('bongchay_30fps457833mslong                        ', '175500ms  ', '177000ms  ', 'man in red shirt and black shirt and white shirt is holding up his head')
# ('bongchay_30fps457833mslong                        ', '177000ms  ', '177500ms  ', 'two wrestlers reach to get ball in the air')
# ('bongchay_30fps457833mslong                        ', '177500ms  ', '178000ms  ', 'man in white shirt and white shorts is playing with the ball')
# ('bongchay_30fps457833mslong                        ', '178000ms  ', '180000ms  ', 'two men in white and white uniforms playing game')
# ('bongchay_30fps457833mslong                        ', '180000ms  ', '180500ms  ', 'man in red shirt is jumping over red and white ramp')
# ('bongchay_30fps457833mslong                        ', '180500ms  ', '181000ms  ', 'two people are sitting on the side of the road')
# ('bongchay_30fps457833mslong                        ', '181000ms  ', '182000ms  ', 'two people are sitting on the grass and one has the other in the air')
# ('bongchay_30fps457833mslong                        ', '182000ms  ', '182500ms  ', 'the is off the white and white motorcycle')
# ('bongchay_30fps457833mslong                        ', '182500ms  ', '183000ms  ', 'two people are sitting in the grass')
# ('bongchay_30fps457833mslong                        ', '183000ms  ', '183500ms  ', 'the is in the red race car is in the air')
# ('bongchay_30fps457833mslong                        ', '183500ms  ', '184000ms  ', 'two men are playing cricket in race')
# ('bongchay_30fps457833mslong                        ', '184000ms  ', '185000ms  ', 'man in yellow jersey is jumping over red and white obstacle')
# ('bongchay_30fps457833mslong                        ', '185000ms  ', '185500ms  ', 'the black and white dog is jumping over the red and white ramp')
# ('bongchay_30fps457833mslong                        ', '185500ms  ', '186000ms  ', 'man in red shirt is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '186000ms  ', '186500ms  ', 'man in red shirt and black shorts is playing cricket')
# ('bongchay_30fps457833mslong                        ', '186500ms  ', '187000ms  ', 'man in red shirt and black shorts is jumping over white and white bull')
# ('bongchay_30fps457833mslong                        ', '187000ms  ', '187500ms  ', 'two men in blue and white uniforms are playing cricket')
# ('bongchay_30fps457833mslong                        ', '187500ms  ', '188500ms  ', 'two wrestlers wrestlers in the air')
# ('bongchay_30fps457833mslong                        ', '188500ms  ', '189000ms  ', 'two men are playing football in field')
# ('bongchay_30fps457833mslong                        ', '189000ms  ', '190000ms  ', 'two men in red and white jerseys are playing with their dogs')
# ('bongchay_30fps457833mslong                        ', '190000ms  ', '190500ms  ', 'two wrestlers in the ring')
# ('bongchay_30fps457833mslong                        ', '190500ms  ', '191000ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '191000ms  ', '191500ms  ', 'two wrestlers teams in the air')
# ('bongchay_30fps457833mslong                        ', '191500ms  ', '192000ms  ', 'two men in black and white jump over the side of the')
# ('bongchay_30fps457833mslong                        ', '192000ms  ', '193000ms  ', 'two wrestlers reach to get ball in the air')
# ('bongchay_30fps457833mslong                        ', '193000ms  ', '195500ms  ', 'two men in white and white and white and white and white and white and white and white and white and white and white and white and white and white and white and white')
# ('bongchay_30fps457833mslong                        ', '195500ms  ', '197500ms  ', 'two men are playing frisbee on the track')
# ('bongchay_30fps457833mslong                        ', '197500ms  ', '198000ms  ', 'man in red shirt is jumping over red barrel')
# ('bongchay_30fps457833mslong                        ', '198000ms  ', '201000ms  ', 'two men are playing cricket in the air')
# ('bongchay_30fps457833mslong                        ', '201000ms  ', '201500ms  ', 'man in red shirt is jumping over red and white bull')
# ('bongchay_30fps457833mslong                        ', '201500ms  ', '202000ms  ', 'man in black and white uniform dives over hurdle')
# ('bongchay_30fps457833mslong                        ', '202000ms  ', '202500ms  ', 'dog is jumping over white and white dog')
# ('bongchay_30fps457833mslong                        ', '202500ms  ', '203000ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '203000ms  ', '204000ms  ', 'two wrestlers wrestlers in the air')
# ('bongchay_30fps457833mslong                        ', '204000ms  ', '204500ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '204500ms  ', '205500ms  ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '205500ms  ', '207000ms  ', 'man in purple shirt is jumping over white and white fence')
# ('bongchay_30fps457833mslong                        ', '207000ms  ', '207500ms  ', 'two dogs are playing with ball in the air')
# ('bongchay_30fps457833mslong                        ', '207500ms  ', '208000ms  ', 'dog is jumping up to catch ball in its mouth')
# ('bongchay_30fps457833mslong                        ', '208000ms  ', '209000ms  ', 'man in white shirt and white shorts is running in the grass')
# ('bongchay_30fps457833mslong                        ', '209000ms  ', '209500ms  ', 'two people are sitting on the side of the road')
# ('bongchay_30fps457833mslong                        ', '209500ms  ', '210000ms  ', 'black and white dog is running on the grass')
# ('bongchay_30fps457833mslong                        ', '210000ms  ', '211000ms  ', 'pitcher in blue and white uniform is playing tennis')
# ('bongchay_30fps457833mslong                        ', '211000ms  ', '211500ms  ', 'dog jumps over hurdle')
# ('bongchay_30fps457833mslong                        ', '211500ms  ', '212000ms  ', 'pitcher in blue and white uniform hits baseball')
# ('bongchay_30fps457833mslong                        ', '212000ms  ', '212500ms  ', 'dog is running on the sand')
# ('bongchay_30fps457833mslong                        ', '212500ms  ', '213000ms  ', 'dog is jumping up to catch ball in its mouth')
# ('bongchay_30fps457833mslong                        ', '213000ms  ', '214000ms  ', 'man in blue shirt and black shorts is jumping over white and white dog')
# ('bongchay_30fps457833mslong                        ', '214000ms  ', '215000ms  ', 'football player in red uniform is running with the ball in the stadium')
# ('bongchay_30fps457833mslong                        ', '215000ms  ', '215500ms  ', 'two men are playing football in field')
# ('bongchay_30fps457833mslong                        ', '215500ms  ', '216000ms  ', 'man in yellow shirt and jeans is jumping on the grass')
# ('bongchay_30fps457833mslong                        ', '216000ms  ', '217500ms  ', 'man in red shirt and jeans is jumping over red and white slide')
# ('bongchay_30fps457833mslong                        ', '217500ms  ', '218000ms  ', 'child in yellow shirt is jumping into the air')
# ('bongchay_30fps457833mslong                        ', '218000ms  ', '218500ms  ', 'man in red shirt and black shorts is jumping over white and white bull')
# ('bongchay_30fps457833mslong                        ', '218500ms  ', '219000ms  ', 'boy in yellow shirt is jumping into the air')
# ('bongchay_30fps457833mslong                        ', '219000ms  ', '219500ms  ', 'two children are playing on swing')
# ('bongchay_30fps457833mslong                        ', '219500ms  ', '220000ms  ', 'man in red shirt and black shorts is holding up his head')
# ('bongchay_30fps457833mslong                        ', '220000ms  ', '221000ms  ', 'man in red shirt and white shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '221000ms  ', '221500ms  ', 'man in blue shirt and blue shorts is holding up his head')
# ('bongchay_30fps457833mslong                        ', '221500ms  ', '222000ms  ', 'football player in red and white jersey is being by crowd')
# ('bongchay_30fps457833mslong                        ', '222000ms  ', '222500ms  ', 'two men in black and white uniforms are playing with ball')
# ('bongchay_30fps457833mslong                        ', '222500ms  ', '223000ms  ', 'two wrestlers are competing in race')
# ('bongchay_30fps457833mslong                        ', '223000ms  ', '224000ms  ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '224000ms  ', '224500ms  ', 'two men in blue and white uniforms playing game')
# ('bongchay_30fps457833mslong                        ', '224500ms  ', '225500ms  ', 'group of people are sitting in front of an audience')
# ('bongchay_30fps457833mslong                        ', '225500ms  ', '227000ms  ', 'man in black shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '227000ms  ', '228000ms  ', 'two people are sitting on the street')
# ('bongchay_30fps457833mslong                        ', '228000ms  ', '229000ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '229000ms  ', '229500ms  ', 'wrestler in white uniform is jumping up from the air while another boy watches')
# ('bongchay_30fps457833mslong                        ', '229500ms  ', '230000ms  ', 'man in red shirt is jumping over bull')
# ('bongchay_30fps457833mslong                        ', '230000ms  ', '231000ms  ', 'man in red shirt and white shirt is playing cricket')
# ('bongchay_30fps457833mslong                        ', '231000ms  ', '232000ms  ', 'horse rider jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '232000ms  ', '232500ms  ', 'man in red shirt is jumping over white and white ramp')
# ('bongchay_30fps457833mslong                        ', '232500ms  ', '233000ms  ', 'the woman is performing trick on the track')
# ('bongchay_30fps457833mslong                        ', '233000ms  ', '233500ms  ', 'two sumo wrestlers are competing around the line')
# ('bongchay_30fps457833mslong                        ', '233500ms  ', '235000ms  ', 'man in red shirt is standing in front of red truck')
# ('bongchay_30fps457833mslong                        ', '235000ms  ', '237500ms  ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '237500ms  ', '238000ms  ', 'two sumo wrestlers in match')
# ('bongchay_30fps457833mslong                        ', '238000ms  ', '238500ms  ', 'pitcher in blue and white uniform is playing baseball')
# ('bongchay_30fps457833mslong                        ', '238500ms  ', '239000ms  ', 'pitcher in blue shirt and white shorts is running on the field')
# ('bongchay_30fps457833mslong                        ', '239000ms  ', '239500ms  ', 'dog is jumping over white and white dog')
# ('bongchay_30fps457833mslong                        ', '239500ms  ', '240000ms  ', 'baseball player in black and white uniform is running')
# ('bongchay_30fps457833mslong                        ', '240000ms  ', '240500ms  ', 'man in purple shirt and white shorts is running on the grass')
# ('bongchay_30fps457833mslong                        ', '240500ms  ', '241000ms  ', 'pitcher in white and white uniform is playing frisbee')
# ('bongchay_30fps457833mslong                        ', '241000ms  ', '242500ms  ', 'baseball player in black and white uniform is running on the field')
# ('bongchay_30fps457833mslong                        ', '242500ms  ', '243000ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '243000ms  ', '243500ms  ', 'man in blue shirt and black shorts is jumping over red and white bull')
# ('bongchay_30fps457833mslong                        ', '243500ms  ', '244000ms  ', 'two wrestlers are playing cricket in race')
# ('bongchay_30fps457833mslong                        ', '244000ms  ', '244500ms  ', 'two wrestlers reach to catch ball')
# ('bongchay_30fps457833mslong                        ', '244500ms  ', '245000ms  ', 'baseball player in black is jumping over the goal')
# ('bongchay_30fps457833mslong                        ', '245000ms  ', '245500ms  ', 'two wrestlers in black and white uniforms are playing with the ball')
# ('bongchay_30fps457833mslong                        ', '245500ms  ', '246000ms  ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '246000ms  ', '246500ms  ', 'two dogs are playing with red and white toy')
# ('bongchay_30fps457833mslong                        ', '246500ms  ', '247500ms  ', 'two people are sitting on bench with their heads in the background')
# ('bongchay_30fps457833mslong                        ', '247500ms  ', '248500ms  ', 'black and white dog is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '248500ms  ', '254000ms  ', 'man in red shirt is jumping over red and white and white dog')
# ('bongchay_30fps457833mslong                        ', '254000ms  ', '254500ms  ', 'two men are playing football')
# ('bongchay_30fps457833mslong                        ', '254500ms  ', '255000ms  ', 'man in red shirt and black shorts is jumping over an audience')
# ('bongchay_30fps457833mslong                        ', '255000ms  ', '255500ms  ', 'man in yellow shirt and blue helmet is playing with colorful and colorful pole')
# ('bongchay_30fps457833mslong                        ', '255500ms  ', '256000ms  ', 'man in blue shirt is jumping over red and white and white motorcycle')
# ('bongchay_30fps457833mslong                        ', '256000ms  ', '256500ms  ', 'two men are playing cricket on the grass')
# ('bongchay_30fps457833mslong                        ', '256500ms  ', '257000ms  ', 'man in blue shirt and blue shorts is jumping over the ground')
# ('bongchay_30fps457833mslong                        ', '257000ms  ', '258000ms  ', 'man in red shirt and white shirt and white shirt is holding football')
# ('bongchay_30fps457833mslong                        ', '258000ms  ', '261000ms  ', 'man in red shirt and black shirt and black shirt holding white and white and white and white and white and white uniforms')
# ('bongchay_30fps457833mslong                        ', '261000ms  ', '262000ms  ', 'man in red shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt')
# ('bongchay_30fps457833mslong                        ', '262000ms  ', '262500ms  ', 'two people are sitting in the bull')
# ('bongchay_30fps457833mslong                        ', '262500ms  ', '263500ms  ', 'two men are sitting in the air in parade')
# ('bongchay_30fps457833mslong                        ', '263500ms  ', '264000ms  ', 'crowd of people are waving american flags')
# ('bongchay_30fps457833mslong                        ', '264000ms  ', '264500ms  ', 'two men are sitting in line')
# ('bongchay_30fps457833mslong                        ', '264500ms  ', '265000ms  ', 'crowd of people are all in the air')
# ('bongchay_30fps457833mslong                        ', '265000ms  ', '265500ms  ', 'crowd of people are standing in crowd of people')
# ...
# ('bongchay_30fps457833mslong                        ', '391500ms  ', '392000ms  ', 'man in red shirt and white shirt and white shirt is holding football')
# ('bongchay_30fps457833mslong                        ', '392000ms  ', '393500ms  ', 'man in red shirt and blue shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt')
# ('bongchay_30fps457833mslong                        ', '393500ms  ', '394500ms  ', 'two wrestlers reach to get ball in the air')
# ('bongchay_30fps457833mslong                        ', '394500ms  ', '395000ms  ', 'two men are playing baseball dive in the air')
# ('bongchay_30fps457833mslong                        ', '395000ms  ', '396000ms  ', 'wrestler in white is jumping over white and white bull')
# ('bongchay_30fps457833mslong                        ', '396000ms  ', '396500ms  ', 'man in purple shirt and black shorts is jumping over red barrier')
# ('bongchay_30fps457833mslong                        ', '396500ms  ', '397000ms  ', 'man in blue shirt is jumping up of the air')
# ('bongchay_30fps457833mslong                        ', '397000ms  ', '397500ms  ', 'football player in red is being by crowd')
# ('bongchay_30fps457833mslong                        ', '397500ms  ', '398500ms  ', 'two men in red jerseys are playing football')
# ('bongchay_30fps457833mslong                        ', '398500ms  ', '400000ms  ', 'man in blue and white uniform is running in front of crowd')
# ('bongchay_30fps457833mslong                        ', '400000ms  ', '401500ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '401500ms  ', '403500ms  ', 'baseball player in blue and white uniform is being ridden by the ball')
# ('bongchay_30fps457833mslong                        ', '403500ms  ', '404000ms  ', 'horse is jumping over hurdle')
# ('bongchay_30fps457833mslong                        ', '404000ms  ', '408000ms  ', 'two men are playing baseball on the field')
# ('bongchay_30fps457833mslong                        ', '408000ms  ', '409000ms  ', 'two men in red and white jerseys are playing cricket')
# ('bongchay_30fps457833mslong                        ', '409000ms  ', '409500ms  ', 'baseball player in black is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '409500ms  ', '410000ms  ', 'man in red shirt and blue helmet is riding bicycle')
# ('bongchay_30fps457833mslong                        ', '410000ms  ', '410500ms  ', 'two men in red and white uniforms are riding in the street')
# ('bongchay_30fps457833mslong                        ', '410500ms  ', '411000ms  ', 'man in blue shirt and blue shirt and black shorts is holding up his head')
# ('bongchay_30fps457833mslong                        ', '411000ms  ', '412500ms  ', 'man in red shirt and black shirt and black shirt and black hat is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '412500ms  ', '413000ms  ', 'the girl in the red shirt is raising the ball in the air')
# ('bongchay_30fps457833mslong                        ', '413000ms  ', '414500ms  ', 'woman in red shirt and black shirt and black beard and black beard and white shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '414500ms  ', '415500ms  ', 'baseball player in blue uniform is jumping in the air')
# ('bongchay_30fps457833mslong                        ', '415500ms  ', '416000ms  ', 'two men playing softball')
# ('bongchay_30fps457833mslong                        ', '416000ms  ', '416500ms  ', 'two men in baseball game')
# ('bongchay_30fps457833mslong                        ', '416500ms  ', '417000ms  ', 'two wrestlers in the ring')
# ('bongchay_30fps457833mslong                        ', '417000ms  ', '418000ms  ', 'two wrestlers reach to get ball in the air')
# ('bongchay_30fps457833mslong                        ', '418000ms  ', '419000ms  ', 'man in red shirt and black shorts is jumping over red barrel')
# ('bongchay_30fps457833mslong                        ', '419000ms  ', '420000ms  ', 'two people are sitting in the air in the air')
# ('bongchay_30fps457833mslong                        ', '420000ms  ', '420500ms  ', 'motocross racers in front of the goal')
# ('bongchay_30fps457833mslong                        ', '420500ms  ', '421000ms  ', 'two men in red and white are playing football')
# ('bongchay_30fps457833mslong                        ', '421000ms  ', '421500ms  ', 'crowd of people are sitting around stadium')
# ('bongchay_30fps457833mslong                        ', '421500ms  ', '422000ms  ', 'the motocross racers take the line as fans cheer')
# ('bongchay_30fps457833mslong                        ', '422000ms  ', '422500ms  ', 'the is player in the air')
# ('bongchay_30fps457833mslong                        ', '422500ms  ', '423000ms  ', 'the football player is being by the player in white')
# ('bongchay_30fps457833mslong                        ', '423000ms  ', '424500ms  ', 'two men are playing football on the field')
# ('bongchay_30fps457833mslong                        ', '424500ms  ', '425000ms  ', 'man in red shirt and white shirt is holding basketball')
# ('bongchay_30fps457833mslong                        ', '425000ms  ', '425500ms  ', 'man in blue uniform and white shirt and blue shorts is playing baseball')
# ('bongchay_30fps457833mslong                        ', '425500ms  ', '426000ms  ', 'baseball player in red uniform is running with his head in the background')
# ('bongchay_30fps457833mslong                        ', '426000ms  ', '427000ms  ', 'man in blue shirt and blue shorts is running in the field')
# ('bongchay_30fps457833mslong                        ', '427000ms  ', '429000ms  ', 'woman in red shirt and black shorts is holding up her feet in front of crowd')
# ('bongchay_30fps457833mslong                        ', '429000ms  ', '430500ms  ', 'man in blue shirt and white shirt is holding football in his hand')
# ('bongchay_30fps457833mslong                        ', '430500ms  ', '431000ms  ', 'man in red shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt holding white and white and white shirt')
# ('bongchay_30fps457833mslong                        ', '431000ms  ', '431500ms  ', 'wrestler in the air is jumping up of the air')
# ('bongchay_30fps457833mslong                        ', '431500ms  ', '432000ms  ', 'two men jump over an obstacle')
# ('bongchay_30fps457833mslong                        ', '432000ms  ', '432500ms  ', 'baseball player in black is playing softball')
# ('bongchay_30fps457833mslong                        ', '432500ms  ', '433000ms  ', 'man in red shirt and black shorts is playing with toy')
# ('bongchay_30fps457833mslong                        ', '433000ms  ', '435000ms  ', 'man in black shirt and black pants is sitting on the beach')
# ('bongchay_30fps457833mslong                        ', '435000ms  ', '438500ms  ', 'man in blue shirt and black shorts is jumping over red and white fence')
# ('bongchay_30fps457833mslong                        ', '438500ms  ', '439000ms  ', 'two men are playing frisbee on the grass')
# ('bongchay_30fps457833mslong                        ', '439000ms  ', '439500ms  ', 'two sumo wrestlers are playing cricket')
# ('bongchay_30fps457833mslong                        ', '439500ms  ', '440000ms  ', 'man in red shirt and black shorts is holding up his head')
# ('bongchay_30fps457833mslong                        ', '440000ms  ', '440500ms  ', 'two girls in red and white uniforms are playing with ball')
# ('bongchay_30fps457833mslong                        ', '440500ms  ', '441000ms  ', 'woman in red shirt and black shirt is standing in front of crowd')
# ('bongchay_30fps457833mslong                        ', '441000ms  ', '441500ms  ', 'two men are sitting in the grass')
# ('bongchay_30fps457833mslong                        ', '441500ms  ', '442000ms  ', 'man in white shirt and white shirt is running in front of crowd')
# ('bongchay_30fps457833mslong                        ', '442000ms  ', '442500ms  ', 'group of men are playing soccer')
# ('bongchay_30fps457833mslong                        ', '442500ms  ', '443000ms  ', 'group of men are playing frisbee in front of crowd')
# ('bongchay_30fps457833mslong                        ', '443000ms  ', '444500ms  ', 'man in white shirt and white shirt is raising her head in crowd of people')
# ('bongchay_30fps457833mslong                        ', '444500ms  ', '447500ms  ', 'black and white dog is jumping over white and white bull')
# ('bongchay_30fps457833mslong                        ', '447500ms  ', '448000ms  ', 'wrestler in purple shirt is trying to catch frisbee')
# ('bongchay_30fps457833mslong                        ', '448000ms  ', '448500ms  ', 'wrestler in white shirt is playing with crowd')
# ('bongchay_30fps457833mslong                        ', '448500ms  ', '449000ms  ', 'group of people are playing soccer')
# ('bongchay_30fps457833mslong                        ', '449000ms  ', '449500ms  ', 'man in white shirt and white shirt is playing with crowd')
# ('bongchay_30fps457833mslong                        ', '449500ms  ', '450000ms  ', 'group of people are standing around in line')
# ('bongchay_30fps457833mslong                        ', '450000ms  ', '452500ms  ', 'wrestler in white is playing with white and white dog')
# ('bongchay_30fps457833mslong                        ', '452500ms  ', '457500ms  ', 'man in leather is standing on the beach')
# ('CrashLandingOnYou_23fps42173mslong                ', '0ms       ', '1000ms    ', 'man with long hair and ponytail is sitting on bench with his arms crossed')
# ('CrashLandingOnYou_23fps42173mslong                ', '1000ms    ', '1500ms    ', 'man in black shirt and black hat is sitting on bench overlooking the grass')
# ('CrashLandingOnYou_23fps42173mslong                ', '1500ms    ', '2000ms    ', 'young girl in black jacket is standing in front of bushes')
# ('CrashLandingOnYou_23fps42173mslong                ', '2000ms    ', '2500ms    ', 'young girl in green shirt and green shirt is walking on the grass')
# ('CrashLandingOnYou_23fps42173mslong                ', '2500ms    ', '3000ms    ', 'man in hat and hat is hiking on trail')
# ('CrashLandingOnYou_23fps42173mslong                ', '3000ms    ', '4500ms    ', 'man in black shirt and black shirt is standing in front of crowd')
# ('CrashLandingOnYou_23fps42173mslong                ', '4500ms    ', '5500ms    ', 'group of people are sitting on the beach')
# ('CrashLandingOnYou_23fps42173mslong                ', '5500ms    ', '6000ms    ', 'man in red shirt is standing on the street')
# ('CrashLandingOnYou_23fps42173mslong                ', '6000ms    ', '7000ms    ', 'man in green shirt and jeans is standing on bench in front of crowd')
# ('CrashLandingOnYou_23fps42173mslong                ', '7000ms    ', '7500ms    ', 'woman with glasses and woman in black dress are sitting in front of wall')
# ('CrashLandingOnYou_23fps42173mslong                ', '7500ms    ', '9000ms    ', 'girl in pink shirt and black shirt is sitting in front of window')
# ('CrashLandingOnYou_23fps42173mslong                ', '9000ms    ', '9500ms    ', 'station')
# ('CrashLandingOnYou_23fps42173mslong                ', '9500ms    ', '11000ms   ', 'group of people are sitting in the mud')
# ('CrashLandingOnYou_23fps42173mslong                ', '11000ms   ', '12500ms   ', 'man in black shirt and black shirt is standing in front of window')
# ('CrashLandingOnYou_23fps42173mslong                ', '12500ms   ', '14000ms   ', 'woman in red shirt and tie and woman in black dress are sitting in crowd')
# ('CrashLandingOnYou_23fps42173mslong                ', '14000ms   ', '16500ms   ', 'man in green shirt and black shirt is standing in front of wall')
# ('CrashLandingOnYou_23fps42173mslong                ', '16500ms   ', '17000ms   ', 'man with woman sit on the phone')
# ('CrashLandingOnYou_23fps42173mslong                ', '17000ms   ', '18000ms   ', 'man in black shirt and black shirt is standing in front of white building')
# ('CrashLandingOnYou_23fps42173mslong                ', '18000ms   ', '18500ms   ', 'diver diver approaches the water')
# ('CrashLandingOnYou_23fps42173mslong                ', '18500ms   ', '19000ms   ', 'man in red shirt is sitting on bench')
# ('CrashLandingOnYou_23fps42173mslong                ', '19000ms   ', '20000ms   ', 'woman in an orange shirt is sitting in front of bus')
# ('CrashLandingOnYou_23fps42173mslong                ', '20000ms   ', '20500ms   ', 'group of people are sitting on bench in field')
# ('CrashLandingOnYou_23fps42173mslong                ', '20500ms   ', '21000ms   ', 'two men in field and one is holding camera')
# ('CrashLandingOnYou_23fps42173mslong                ', '21000ms   ', '22000ms   ', 'little girl in red shirt and black shirt is holding camera')
# ('CrashLandingOnYou_23fps42173mslong                ', '22000ms   ', '22500ms   ', 'woman in red shirt is sitting on the beach')
# ('CrashLandingOnYou_23fps42173mslong                ', '22500ms   ', '24000ms   ', 'woman with long hair and sunglasses is standing next to woman with sunglasses')
# ('CrashLandingOnYou_23fps42173mslong                ', '24000ms   ', '24500ms   ', 'man and woman sit on the phone')
# ('CrashLandingOnYou_23fps42173mslong                ', '24500ms   ', '25000ms   ', 'woman in black shirt and black shirt is standing in front of fireplace')
# ('CrashLandingOnYou_23fps42173mslong                ', '25000ms   ', '26000ms   ', 'group of people are posing for picture')
# ('CrashLandingOnYou_23fps42173mslong                ', '26000ms   ', '27500ms   ', 'group of people are sitting on the beach')
# ('CrashLandingOnYou_23fps42173mslong                ', '27500ms   ', '28000ms   ', 'man with beard hair and black beard and black beard is holding her hand in the air')
# ('CrashLandingOnYou_23fps42173mslong                ', '28000ms   ', '29000ms   ', 'woman in red shirt and black shirt is standing in front of crowd')
# ('CrashLandingOnYou_23fps42173mslong                ', '29000ms   ', '30000ms   ', 'two people are sitting on roof ledge and blowing the water')
# ('CrashLandingOnYou_23fps42173mslong                ', '30000ms   ', '30500ms   ', 'wrestler in red shirt is doing stunt')
# ('CrashLandingOnYou_23fps42173mslong                ', '30500ms   ', '33500ms   ', 'man in red shirt and black shorts is standing on the beach')
# ('CrashLandingOnYou_23fps42173mslong                ', '33500ms   ', '34500ms   ', 'the little girl is jumping up of the wall')
# ('CrashLandingOnYou_23fps42173mslong                ', '34500ms   ', '35000ms   ', 'man in leather is sitting on the street')
# ('girl_17fps9117mslong                              ', '0ms       ', '1500ms    ', 'girl with hair hair head head head head head head head head head head')
# ('girl_17fps9117mslong                              ', '1500ms    ', '3000ms    ', 'blond girl with hair hair blowing her nose')
# ('girl_17fps9117mslong                              ', '3000ms    ', '4000ms    ', 'blond girl in green shirt is holding up her nose')
# ('girl_17fps9117mslong                              ', '4000ms    ', '4500ms    ', 'blond girl with hair hair blowing her head')
# ('girl_17fps9117mslong                              ', '4500ms    ', '5500ms    ', 'blond girl in green shirt smiles')
# ('girl_17fps9117mslong                              ', '5500ms    ', '6000ms    ', 'blond girl wears denim head')
# ('girl_17fps9117mslong                              ', '6000ms    ', '6500ms    ', 'blond girl with hair hair nose')
# ('girl_17fps9117mslong                              ', '6500ms    ', '7000ms    ', 'blond girl wears denim head')
# ('girl_17fps9117mslong                              ', '7000ms    ', '7500ms    ', 'blond girl with hair hair blowing her nose')
# ('girl_17fps9117mslong                              ', '7500ms    ', '9117ms    ', 'blond girl with hair hair and pink shirt')

# %%
"\\dob.mp4".replace("\\", "/")
# Out:
# '/dob.mp4'

# %%
#[NOTICE]this is the caption video function had the progress details
def caption_this_video_details(input_video, similar_rate):
    try:
        #creating a folder named data
        if not os.path.exists('data'):
            os.mkdir('data')
    except OSError:
        print('Error: Existed folder!')

    video_to_capture = cv2.VideoCapture(input_video)
    video_name = get_video_name(input_video, '.mp4')
    print('Video name: ' + video_name + '.mp4')
    count = 0
    prev_caption = ''
    while(True):
        ret, frame = video_to_capture.read()
        if ret:
            video_to_capture.set(cv2.CAP_PROP_POS_MSEC, (count*500))
            temp_path = './data/' + video_name + '.jpg'
            cv2.imwrite(temp_path, frame)
            current_caption = caption_this_image(temp_path)
            r = same_rate(current_caption, prev_caption)
            if count == 0:
                print('Start at: '  + str(count*500) + 'ms :' + current_caption)
                print('-------------------------------------------------------' + str(count))
                prev_caption = current_caption
            elif (count > 0) and (r >= similar_rate):
                print('Skip ' + str(count*500) + ' ms : similar_rate = ' + str(r*100) +'%')
                print('-------------------------------------------------------' + str(count))
            else:
                print((count > 0) and (r >= similar_rate))
                print('current: ' + current_caption)
                print('prev: ' + prev_caption)
                print('similar_rate =' + str(same_rate(current_caption, prev_caption)*100) + '%')
                print(str(count*500) + 'ms :' + current_caption)
                print('-------------------------------------------------------' + str(count))
                prev_caption = current_caption
                
            os.remove(temp_path)
            count += 1
        else:
            break
    video_to_capture.release()
    cv2.destroyAllWindows()

#caption_this_video_details('D:/University/cat2.mp4', 0.6)
#caption_this_video_details('C:/\DeployImageCaptioning/cat.mp4', 0.6)

# %%
import re
from functools import reduce
#split function: split a list into list of list by a element inside the list
def split(iterable, where):
    def splitter(acc, item, where=where):
        if item == where:
            acc.append([])
        else:
            acc[-1].append(item)
        return acc
    return reduce(splitter, iterable, [[]])

#get timeline of a object (keyword)
def get_timeline(keyword):
    timeline = [0]
    cursor.execute("SELECT * FROM Caption WHERE Decription like ?", '%{}%'.format(keyword)) 
    rows = cursor.fetchall()
    for row in rows:
        start = re.sub("[^0-9]", "",row.Start)
        end = re.sub("[^0-9]", "",row.Stop)
        if (int(start) - timeline[-1]) >= 2000:
            timeline.append('break')
            timeline.append(int(start))
        else:
            if int(start) not in timeline:
                timeline.append(int(start))
        timeline.append(int(end))
    timeline = split(timeline, 'break')
    return timeline

# %%
time = get_timeline("dog")
print(time)
# Out:
# [[0], [6000, 6500, 7000, 8500, 10000, 11000, 12000, 12500, 14000, 14500, 16500, 17000, 18500, 19000, 19680, 20000]]

# %%
import shutil
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.editor import VideoFileClip, concatenate_videoclips

def process_video(path, timeline):
    #create temporary folder called data to save the temporary caption image
    #shutil.rmtree('C:/DeployImageCaptioning/video')
    folder = 'video/'
    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))
    try:
        #creating a folder named data
        if not os.path.exists('video'):
            os.mkdir('video')
    except OSError:
        print('Error: Existed folder!')
    video_name = get_video_name(path, '.mp4')
    clips = []
    for t in timeline:
        if len(t) > 1:
            starttime = t[0]/1000
            endtime = t[-1]/1000
            targetname="video/"+video_name+str(timeline.index(t)+1)+".mp4"
            ffmpeg_extract_subclip(path, starttime, endtime, targetname)
            clips.append(VideoFileClip(targetname))
            #clips.append([starttime, endtime])
    print(clips)
    #final_clip = concatenate_videoclips(clips)
    #final_clip.write_videofile("video/"+video_name+"final.mp4")
timeline = get_timeline("man")
process_video(input_video, timeline)
# Out:
# Failed to delete video/demo2.mp4. Reason: [WinError 32] The process cannot access the file because it is being used by another process: 'video/demo2.mp4'
# Failed to delete video/demo3.mp4. Reason: [WinError 32] The process cannot access the file because it is being used by another process: 'video/demo3.mp4'
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# [<moviepy.video.io.VideoFileClip.VideoFileClip object at 0x0000018DBB21B7C8>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x0000018DBF76FB48>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x0000018DBF76C248>]
